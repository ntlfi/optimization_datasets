# %%
import numpy as np
import pandas as pd
import re

# %%
# Read the data from the CSV file
df = pd.read_csv('child_care_regulated.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15540 entries, 0 to 15539
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   facility_id           15540 non-null  int64
#  1   program_type          15540 non-null  object
#  2   facility_status       15540 non-null  object
#  3   facility_name         15540 non-null  object
#  4   city                  15540 non-null  object
#  5   zip_code              15540 non-null  int64
#  6   school_district_name  15492 non-null  object
#  7   infant_capacity       15540 non-null  int64
#  8   toddler_capacity      15540 non-null  int64
#  9   preschool_capacity    15540 non-null  int64
#  10  school_age_capacity   15540 non-null  int64
#  11  children_capcity      15540 non-null  int64
#  12  total_capacity        15540 non-null  int64
# dtypes: int64(8), object(5)
# memory usage: 1.5+ MB

# %%
df.loc[0]['sum']
# Out:
# 14

# %%
re.split(' AND ', seq[0])
# Out:
# ['12 children, ages 6 weeks to 12 years', '2 additional school-aged children']

# %%
df
# Out:
#        facility_id program_type region_code         county facility_status  \
# 0               14         GFDC         ARO         Albany         License
# 1             5555          FDC         BRO     Chautauqua    Registration
# 2            40414          DCC         YRO       Sullivan         License
# 3            40542          DCC         YRO    Westchester         License
# 4            44327          DCC         SRO   St. Lawrence         License
# ...            ...          ...         ...            ...             ...
# 15535       891027          DCC         ARO       Delaware         License
# 15536       895173         SACC      NYCDOH  Staten Island    Registration
# 15537       900037          DCC         YRO    Westchester         License
# 15538       890593         GFDC      NYCDOH          Bronx         License
# 15539       909160         GFDC      NYCDOH         Queens         License
#
# ...
