# %%
import pandas as pd

# load data
data = pd.read_csv('hourly_ridership_example.csv')

# %%
data
# Out:
#       Unnamed: 0                timestamp station_id  \
# 0              0  2023-12-27T09:00:00.000        228
# 1              1  2023-12-27T09:00:00.000        162
# 2              2  2023-12-27T09:00:00.000        333
# 3              3  2023-12-27T09:00:00.000        477
# 4              4  2023-12-27T09:00:00.000        144
# ...          ...                      ...        ...
# 1061        1061  2023-12-27T09:00:00.000        612
# 1062        1062  2023-12-27T09:00:00.000        610
# 1063        1063  2023-12-27T09:00:00.000        607
# 1064        1064  2023-12-27T09:00:00.000        607
# 1065        1065  2023-12-27T09:00:00.000        277
#
#                             station_name           fare_class_category  \
# 0                            23 St (F,M)   OMNY - Seniors & Disability
# 1                            50 St (C,E)         Metrocard - Full Fare
# 2                          Wall St (2,3)              OMNY - Full Fare
# ...
